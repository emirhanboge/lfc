# %%
import json
import pandas as pd

# %%
f = open("commitstats.txt", "r")
pullr = pd.read_pickle("/content/drive/MyDrive/Learning from Contributions/pytorch_issue_data/pickles/botless_pullr")

# %%
sha_txt = []
for line in f.readlines():
  if "commit" in line:
    sha = line[7:]
    sha_txt.append(sha)

# %%
len(sha_txt)
# Out:
# 14421

# %%
for idx, row in pullr.iterrows():
  if row["sha"] in sha_txt:
    print(row["sha"])
    break
